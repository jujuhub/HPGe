# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Sergey wants to know what we can easily see of Th gamma lines
# and if it's possible to see all the lines (some from U contamination)

# prefixes: background, thoxide, lantern_mantle
# file extensions: .Chn, .Spe

# %%
cnts = np.loadtxt("data/lantern_mantle_20191203.Spe", dtype=int, delimiter='        ', 
                  skiprows=12, max_rows=16384)

print(cnts)
# Out:
# [0 0 0 ... 0 0 5]

# %%
plt.figure(figsize=(15,8))
plt.xlim((0,2700))
plt.plot(cnts)
